# %% [markdown]
# <a href="https://colab.research.google.com/github/elandverymuchnothing/data-analytics/blob/main/6_08_Exploratory_Data_Analysis_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 4.1 Games of Chance
import random
# A. Simulate flipping a coin 100 times, then print the percentage of results that were "heads"


heads = 0

for i in range(100):
    flip = random.choice(["heads", "tails"])

    if flip == "heads":
        heads += 1

percentage = (heads / 100) * 100

print(f"Heads percentage: {percentage}%")
# Out:
# Heads percentage: 44.0%

# %%
# B. Randomly choose an element until you choose "yellow", incrememting flips each time
#    Print a message each time including how many flips have been executed and what the result was
flips = 0
sides = ["blue", "blue", "blue", "blue", "yellow", "blue"]

import random

flips = 0
sides = ["blue", "blue", "blue", "blue", "yellow", "blue"]

result = ""

while result != "yellow":
    result = random.choice(sides)
    flips += 1

    print(f"Flip {flips}: {result}")
# Out:
# Flip 1: blue
# Flip 2: blue
# Flip 3: blue
# Flip 4: blue
# Flip 5: blue
# Flip 6: blue
# Flip 7: yellow

# %%
# C. Simulate a slot machine with the following rules:
#    i. Each turn, the player loses 1 point and three random elements are chosen
#    ii. If the three elements are all the same, the player wins 2 points
#    iii. If all three elements are different, the player wins 5 points
#    Continue taking turns until the player has 0 points or more than 10 points
#    Each turn, print a message describing the outcome of the machine
elements = ["red", "green", "blue"]
player_points = 7

import random

elements = ["red", "green", "blue"]
player_points = 7

while player_points > 0 and player_points <= 10:
    # Lose 1 point each turn
    player_points -= 1

    # Choose 3 random elements
    first = random.choice(elements)
    second = random.choice(elements)
    third = random.choice(elements)

    print(f"{first} | {second} | {third}")

    # All same
    if first == second == third:
        player_points += 2
        print("All matched! +2 points")

    # All different
    elif first != second and second != third and first != third:
        player_points += 5
        print("All different! +5 points")

    else:
        print("No bonus points")

    print(f"Points: {player_points}\n")

# Final message
if player_points <= 0:
    print("Game over!")
else:
    print("You won with more than 10 points!")
# Out:
# green | red | green
# No bonus points
# Points: 6
#
# red | red | red
# All matched! +2 points
# Points: 7
#
# green | green | green
# All matched! +2 points
# Points: 8
#
# blue | blue | green
# No bonus points
# Points: 7
#
# green | green | red
# No bonus points
# Points: 6
#
# red | green | green
# No bonus points
# Points: 5
#
# green | green | red
# No bonus points
# Points: 4
#
# green | green | green
# All matched! +2 points
# Points: 5
#
# red | green | green
# No bonus points
# Points: 4
#
# blue | red | green
# All different! +5 points
# Points: 8
#
# green | red | green
# No bonus points
# Points: 7
#
# blue | red | green
# All different! +5 points
# Points: 11
#
# You won with more than 10 points!

# %%
# 4.2 EDA Demonstration
import pandas as pd
# %matplotlib inline

# %%
# We will store the orders table csv data in a variable
# Tabs are used as the separating character in this file
orders = pd.read_csv("orders.csv", sep="\t")

# %%
# Use the head method to investigate the first row of data
# Show the first 5 rows of the dataset
orders.head(10)
# Out:
#   order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id
# 0  CA-2016-2608109,17/09/2016 00:00,17/09/2016 00...
# 1  ES-2018-1945518,29/08/2018 00:00,02/09/2018 00...
# 2  ES-2018-853948,28/07/2018 00:00,29/07/2018 00:...
# 3  ES-2019-1912507,01/04/2019 00:00,05/04/2019 00...
# 4  ES-2019-2038080,25/03/2019 00:00,28/03/2019 00...
# 5  ID-2019-4299999,28/05/2019 00:00,01/06/2019 00...
# 6  MX-2018-2938153,24/10/2018 00:00,27/10/2018 00...
# 7  MX-2018-3389872,09/12/2018 00:00,11/12/2018 00...
# 8  MX-2018-3434064,30/09/2018 00:00,02/10/2018 00...
# 9  MX-2018-4087259,11/07/2018 00:00,12/07/2018 00...

# %%
# Create a dataframe to view the column names and data types
orders.columns
# Out:
# Index(['order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id'], dtype='object')

# %%
# Use the shape attribute to determine the amount of rows and columns total
orders.shape
# Out:
# (737899, 1)

# %%
# Use the .columns property to list out the column names
print(orders.columns)
# or
print(list(orders.columns))
# Use the .index.name property to identify the index
# Out:
# Index(['order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id'], dtype='object')
# ['order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id']

# %%
# Provide a dictionary to the rename method to rename any columns
# The inplace flag determines whether to modify the original dataframe
orders.rename(columns={
    "old_column_name1": "new_column_name1",
    "old_column_name2": "new_column_name2"
}, inplace=True)

# %%
# Explore columns with column attributes and methods

print(orders.columns)
print(len(orders.columns))
print(list(orders.columns))
# Out:
# Index(['order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id'], dtype='object')
# 1
# ['order_id,order_date,ship_date,ship_mode,customer_id,product_id,sales,quantity,discount,profit,postal_code,region_id']
# False

# %%
# 4.3 Exploring a new dataset
# Import the products.csv dataset and explore the following questions:
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_774/4291389515.py in <cell line: 0>()
#       1 # 4.3 Exploring a new dataset
#       2 # Import the products.csv dataset and explore the following questions:
# ----> 3 products = pd.read_csv("products.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x93 in position 66286: invalid start byte

# %%
# A. What are the columns and index: do they suggest any relationship to other tables?

# %%
# B. How many rows of data are there?

# %%
# C. What are the types of each column?

# %%
# 4.4 Boolean Filtering
# Let's return to the orders dataset for the rest of the challenges
# Use boolean filtering and DataFrame/DataSeries methods to solve the following challanges:

# %%
# A. What is the mean profit of orders where the ship_mode is "Second Class"

# %%
# B. Which product is the most commonly ordered on 2017-06-08

# %%
# 4.5 Sorting and Filtering

# %%
# A. What are the three most profitable orders purchased by customer PO-8865?

# %%
# B. What are the five orders of product_id TEC-HEW-10002304 with the highest quanitity?

# %% [markdown]
# ## Recap
#
# We covered a lot of ground! It's ok if this takes a while to gel.
#
# ```python
#
# # basic DataFrame operations
# df.head()
# df.tail()
# df.shape
# df.columns
# df.Index
#
# # selecting columns
# df.column_name
# df['column_name']
#
# # renaming columns
# df.rename({'old_name':'new_name'}, inplace=True)
# df.columns = ['new_column_a', 'new_column_b']
#
# # notable columns operations
# df.describe() # five number summary
# df['col1'].nunique() # number of unique values
# df['col1'].value_counts() # number of occurrences of each value in column
#
# # filtering
# df[ df['col1'] < 50 ] # filter column to be less than 50
# df[ (df['col1'] == value1) & (df['col2'] > value2) ] # filter column where col1 is equal to value1 AND col2 is greater to value 2
#
# # sorting
# df.sort_values(by='column_name', ascending = False) # sort biggest to smallest
#
# ```
#
#
# It's common to refer back to your own code *all the time.* Don't hesistate to reference this guide! 🐼
